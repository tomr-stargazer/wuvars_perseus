# %%
# %run lightcurve_maker_perseus.py
for offset in np.linspace(-0.1, 0.1, 10):
     this_period = 26.42 + offset
     eightpanel_f95(period=this_period)
# Out:
# Auto-detected table type: fits

# %%
for i, offset in enumerate(np.linspace(0, 0.2, 10)):
     this_period = 26.42 + offset
     eightpanel_f95(period=this_period)
     plt.savefig(f"f95_{i}_period={this_period:.2f}d.png")
